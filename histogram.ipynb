# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Ibscai03.DGVC-MCA/iris.csv")
x=df['sepal lenth']
y=df['sepal width']
plt.xlabel("sepal length")
plt.ylabel("sepal width")
plt.plot(x,y,alpha=1,label="sepal lenth",color='black',linestyle='dashed',linewidth=3,marker='.',markerfacecolor='red',markersize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("C:/Users/Ibscai03.DGVC-MCA/iris.csv")
x=df['sepal lenth']
y=df['sepal width']
plt.xlabel("sepal length")
plt.ylabel("sepal width")
plt.scatter(x,y,color="red",marker="*",s=100,label="mark")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("C:/Users/Ibscai03.DGVC-MCA/iris.csv")
x=df['sepal lenth']
y=df['sepal width']
plt.xlabel("sepal length")
plt.ylabel("sepal width")
plt.bar(x,y,color="red",width=0.5,edgecolor="black",label="bar graph")
plt.legend()
plt.show()

# %%
marks=[50,65,55,70,50,60,85,40,80,75,90,75]
plt.hist(df['sepal lenth'])
# Out:
# (array([ 9., 23., 14., 26., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
mk=pd.Series(marks)
mk
# Out:
# 0     50
# 1     65
# 2     55
# 3     70
# 4     50
# 5     60
# 6     85
# 7     40
# 8     80
# 9     75
# 10    90
# 11    75
# dtype: int64

# %%
mk.plot(kind="density",color="blue",linewidth=2,linestyle="--",label="marks")
plt.legend()
plt.grid(True)
plt.show()

# %%
df.describe()
# Out:
#        sepal lenth  sepal width  petal length  petal width
# count   149.000000   149.000000    148.000000   149.000000
# mean      5.844295     3.054362      3.789865     1.204698
# std       0.830775     0.435034      1.755564     0.762139
# min       4.300000     2.000000      1.000000     0.100000
# 25%       5.100000     2.800000      1.600000     0.300000
# 50%       5.800000     3.000000      4.400000     1.300000
# 75%       6.400000     3.300000      5.100000     1.800000
# max       7.900000     4.400000      6.900000     2.500000
