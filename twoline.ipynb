# %%
import matplotlib.pyplot as plt
x=[101,102,103,104,105]
y=[72,80,67,94,50]
x1=[101,102,103,104,105]
y1=[50,60,70,80,90]
plt.xlabel("Roll no")
plt.ylabel("Marks")
plt.xlim(101,106)
plt.ylim(50,100)
plt.title("student performance")
plt.plot(x,y,label="line-1",color='blue',linestyle='dashed',linewidth=3,marker='D',markerfacecolor='red',markersize=12)
plt.plot(x1,y1,label="line-2",color='green',linestyle='dashed',marker='o',alpha=0.5)
plt.legend()
plt.savefig("sample.png")
plt.show()
